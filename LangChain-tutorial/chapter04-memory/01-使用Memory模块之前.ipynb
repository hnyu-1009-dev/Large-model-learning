# %%
from langchain_openai import ChatOpenAI
import os
import dotenv
from langchain_core.output_parsers import (
    StrOutputParser,
    JsonOutputParser,
)
from langchain_openai import ChatOpenAI
from langchain_core.messages import (
    HumanMessage,
    SystemMessage,
    AIMessage,
)
from langchain_core.prompts import (
    FewShotChatMessagePromptTemplate,
    PromptTemplate,
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    AIMessagePromptTemplate,
    FewShotPromptTemplate,
)

# %%
# 创建大模型
# 加载环境变量
dotenv.load_dotenv(
    # 在工程根目录只保留一个 .env，所有模块都引用它。这是最不容易出错的方式。
    override=True,  # 如果加载.env文件出现了同名环境变脸，会进行覆盖
    # dotenv_path=".env",  # 可以只当需要加载的路径
)


# 1.提供大模型
chat_model = ChatOpenAI(
    api_key=os.getenv("SILICON_FLOW_API_KEY"),
    base_url=os.getenv("SILICON_FLOW_BASE_URL"),
    model="Qwen/Qwen3-8B",  # 确保模型名称准确
)

# %%
def chat_with_model(answer):

    # 2 提供提示词模板：ChatPromptTemplate
    prompt_template = ChatPromptTemplate.from_messages(
        [
            ("system", "你是一个人工智能的助手"),
            ("human", "{question}"),
        ]
    )

    while True:

        # 获取chain 并调用大模型得到响应
        chain = prompt_template | chat_model
        response = chain.invoke({"question": "answer"})
        print(f"模型回复：{response.content}")

        # 继续获取用户的问题
        user_input = input("你还有其他问题吗（输入'退出'时，结束会话）")

        if user_input == "退出":
            break

        # 将上述新生成的消息存放到提示词模板的消息列表中
        prompt_template.messages.append(AIMessage(content=response.content))
        prompt_template.messages.append(HumanMessage(content=user_input))


chat_with_model("你好很高兴认识你")
# Out:
# 模型回复：你好！我是通义千问，一个由通义实验室开发的人工智能助手。我能够帮助你回答问题、创作文字，甚至进行推理和规划。有什么我可以为你做的事情吗？
# 模型回复：“李白很白吗”这个问题其实包含两个层面的含义：一个是指李白的外貌，另一个可能是指他的诗作风格或文学成就。让我从这两个角度来解释：
#
# ---
#
# ### 1. **外貌方面：**
# 关于李白的外貌，历史上并没有太多直接的描述。他的形象更多是通过后人的文学想象和历史评价来塑造的。比如，唐代文人杜甫在《春日忆李白》中写道：
#
# > “白也诗无敌，飘然思不群。”
#
# 这里“白”是李白的字，杜甫称赞他诗才出众，但并没有提到他的外貌是否白皙。至于他的外貌是否“很白”，是后人根据他名字中的“白”字，加上文人常有的意象，进行的一种浪漫化的联想。实际上，这更多是文学修辞，而不是具体描绘。
#
# ---
#
# ### 2. **文学成就方面：**
# 如果问题是从“白”字引申到李白的文采、思想境界，那么可以说“李白很白”是一种赞美。这里的“白”可以理解为“白璧无瑕”“清白高洁”的象征，意味着他的诗风清新脱俗，文采斐然，思想境界高远。例如：
#
# - 他的诗常常表现出豪放不羁、超然物外的气质；
# - 他追求自由与理想，具有极高的艺术表现力和创造性；
# - 他被誉为“诗仙”，其诗作被后人推崇为“白也”。
#
# 因此，说“李白很白”在文学层面是一种褒义的表达，指他诗作的高洁、清白和艺术上的纯粹。
#
# ---
#
# ### 总结：
# “李白很白”可以有两种理解：
# - 一种是字面意思，关于他的外貌，但缺乏可靠的历史记载；
# - 一种是比喻意义，表达对他诗才与人格的赞美。
#
# 你更倾向于哪种理解呢？我可以进一步解释！
