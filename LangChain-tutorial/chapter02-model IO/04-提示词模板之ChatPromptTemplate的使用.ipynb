# %% [markdown]
# # 提示词模板ChatPromptTemplate的使用
# - 1. 实例化的方式（两种方式： 使用构造方法 、 from_messages（））
# - 2. 调用提示词模板的几种方式：invoke()  format()  format_messages()  format_prompt()
# - 3. 更丰富的实例化参数类型
# - 4. 结合LLM
# - 5. 插入消息列表： MessagePlaceholder

# %% [markdown]
# ## 实例化的方式（两种方式： 使用构造方法 、 from_messages（））

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate(
    messages=[
        ("system","你是一个AI助手，你的名字叫{name}"),
        ("human","我问的问题是{question}")
    ],
    input_varibles=["name","question"]
)

responses = chat_prompt_template.invoke(input={"name":"小智","question":"1+2*3=?"})
print(responses)
print(type(responses))
print(len(responses.messages))
# Out:
# messages=[SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我问的问题是1+2*3=?', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>
# 2

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system","你是一个AI助手，你的名字叫{name}"), # 元组（角色：内容）
        ("human","我问的问题是{question}")
    ],
)

responses = chat_prompt_template.invoke(input={"name":"小智","question":"1+2*3=?"})
print(responses)
print(type(responses))
print(len(responses.messages))

# %% [markdown]
# ## 调用提示词模板的几种方式：invoke()  format()  format_messages()  format_prompt()
#
# invoke(): 传入的是字典，返回的是ChatPromptValue
# format(): 传入的是变量的值 返回的是str
# format_messages(): 传入的是变量的值 返回的是list
# format_prompt(): 传入的是变量的值 返回的是ChatPromptValue

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system","你是一个AI助手，你的名字叫{name}"), # 元组（角色：内容）
        ("human","我问的问题是{question}")
    ],
)

responses = chat_prompt_template.invoke(input={"name":"小智","question":"1+2*3=?"})
print(responses)
print(type(responses))
print(len(responses.messages))
# Out:
# messages=[SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我问的问题是1+2*3=?', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>
# 2

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system","你是一个AI助手，你的名字叫{name}"), # 元组（角色：内容）
        ("human","我问的问题是{question}")
    ],
)

responses = chat_prompt_template.format(name="小智",question="1+2*3=?")
print(responses)
print(type(responses))
# Out:
# System: 你是一个AI助手，你的名字叫小智
# Human: 我问的问题是1+2*3=?
# <class 'str'>

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system","你是一个AI助手，你的名字叫{name}"), # 元组（角色：内容）
        ("human","我问的问题是{question}")
    ],
)

responses = chat_prompt_template.format_messages(name="小智",question="1+2*3=?")
print(responses)
print(type(responses))
# Out:
# [SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我问的问题是1+2*3=?', additional_kwargs={}, response_metadata={})]
# <class 'list'>

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system","你是一个AI助手，你的名字叫{name}"), # 元组（角色：内容）
        ("human","我问的问题是{question}")
    ],
)

responses = chat_prompt_template.format_prompt(name="小智",question="1+2*3=?")
print(responses)
print(type(responses))
# Out:
# messages=[SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我问的问题是1+2*3=?', additional_kwargs={}, response_metadata={})]
# <class 'langchain_core.prompt_values.ChatPromptValue'>

# %% [markdown]
# ## 如何实现ChatPromptValue、list[message]、str之间的转换

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "你是一个AI助手，你的名字叫{name}"),  # 元组（角色：内容）
        ("human", "我问的问题是{question}"),
    ],
)

responses = chat_prompt_template.format_prompt(name="小智", question="1+2*3=?")

responses_message = responses.to_messages()
print(responses_message)
print(type(responses_message))

responses_string = responses.to_string()
print(responses_string)
print(type(responses_string))
# Out:
# [SystemMessage(content='你是一个AI助手，你的名字叫小智', additional_kwargs={}, response_metadata={}), HumanMessage(content='我问的问题是1+2*3=?', additional_kwargs={}, response_metadata={})]
# <class 'list'>
# System: 你是一个AI助手，你的名字叫小智
# Human: 我问的问题是1+2*3=?
# <class 'str'>

# %% [markdown]
# ## 更丰富的实例化参数类型
#
# 本质： 不管使用构造方法、还是使用from_message() 来创建ChatPromptTemplate的实例，本质上来讲，传入的都是消息构成的列表。
#
# 从调用上来讲，我们看到的不管使用构造方法，还是使用from_message() 参数类型是多样的。可以是：
#
# message这个列表的元素的类型：字符串类型、字典类型、消息类型、元组构成的列表（最常用、最基础、最简单）Chat提示词模板类型、消息提示词模板类型

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate(
    messages=[
        ("system", "你是一个AI助手，你的名字叫{name}"),
        ("human", "我问的问题是{question}"),
    ],
    input_varibles=["name", "question"],
)

chat_prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "你是一个AI助手，你的名字叫{name}"),  # 元组（角色：内容）
        ("human", "我问的问题是{question}"),
    ],
)
responses = chat_prompt_template.format_prompt(name="小智", question="1+2*3=?")

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    [
        "我问的问题是{question}",  # 默认的角色是：human
    ],
)
responses = chat_prompt_template.format_prompt(question="1+2*3=?")
print(responses)
# Out:
# messages=[HumanMessage(content='我问的问题是1+2*3=?', additional_kwargs={}, response_metadata={})]

# %%
from http.client import responses

from langchain_core.prompts import ChatPromptTemplate

chat_prompt_template = ChatPromptTemplate.from_messages(
    [
        {"role": "system", "content": "你是一个{role}."},
        {"role": "human", "content": ["复杂内容", {"type": "text"}]},
    ],
)
responses = chat_prompt_template.format_prompt(role="教师")
print(responses)
# Out:
# messages=[SystemMessage(content='你是一个教师.', additional_kwargs={}, response_metadata={}), HumanMessage(content=[{'type': 'text', 'text': '复杂内容'}, {'type': 'text'}], additional_kwargs={}, response_metadata={})]

# %%
from langchain_core.prompts import ChatPromptTemplate

# 使用 BaseChatPromptTemplate（嵌套的 ChatPromptTemplate）
nested_prompt_template1 = ChatPromptTemplate.from_messages(
    [("system", "我是一个人工智能助手{role}")]
)
nested_prompt_template2 = ChatPromptTemplate.from_messages([("human", "很高兴认识你{concept}")])
chat_prompt = ChatPromptTemplate.from_messages(
    [nested_prompt_template1, nested_prompt_template2]
)
formatted_messages = chat_prompt.format_messages(role="物理学家", concept="相对论")
print(formatted_messages)
# Out:
# [SystemMessage(content='我是一个人工智能助手物理学家', additional_kwargs={}, response_metadata={}), HumanMessage(content='很高兴认识你相对论', additional_kwargs={}, response_metadata={})]

# %%
# 导入聊天消息类模板
from langchain_core.prompts import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)

# 创建消息模板
system_template = "你是一个专家{role}"
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
human_template = "给我解释{concept}，用浅显易懂的语言"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)
# 组合成聊天提示模板
chat_prompt = ChatPromptTemplate.from_messages(
    [system_message_prompt, human_message_prompt]
)
# 格式化提示
formatted_messages = chat_prompt.format_messages(role="物理学家", concept="相对论")
print(formatted_messages)
# Out:
# [SystemMessage(content='你是一个专家物理学家', additional_kwargs={}, response_metadata={}), HumanMessage(content='给我解释相对论，用浅显易懂的语言', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# ###  结合LLM

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    AIMessagePromptTemplate,
)
import os
import dotenv

# 加载环境变量
dotenv.load_dotenv(
    # 在工程根目录只保留一个 .env，所有模块都引用它。这是最不容易出错的方式。
    override=True,  # 如果加载.env文件出现了同名环境变脸，会进行覆盖
    # dotenv_path=".env",  # 可以只当需要加载的路径
)
chat_model = ChatOpenAI(
    api_key=os.getenv("SILICON_FLOW_API_KEY"),
    base_url=os.getenv("SILICON_FLOW_BASE_URL"),
    model="Qwen/Qwen3-8B",  # 确保模型名称准确
    temperature=0.7,
)

# 生成提示词模板
template = ChatPromptTemplate.from_messages(
    [
        SystemMessagePromptTemplate.from_template(
            "你是{product}的客服助手。你的名字叫{name}"
        ),
        HumanMessagePromptTemplate.from_template("hello 你好吗？"),
        AIMessagePromptTemplate.from_template("我很好 谢谢!"),
        HumanMessagePromptTemplate.from_template("{query}"),
    ]
)
prompt = template.format_messages(product="AGI课堂", name="Bob", query="你是谁")
responses = chat_model.invoke(prompt)
print(responses.content)
# Out:
# 我是Bob，AGI课堂的客服助手。我在这里帮助你解答关于课程、学习、技术等方面的问题。有什么我可以帮你的吗？

# %% [markdown]
# ## 插入消息列表： MessagePlaceholder
#
# 使用场景： 当ChatPromptTemplate模板中的消息和个数不确定时，我们就可以使用MessagePlaceHolder 。 相当于占位

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    AIMessagePromptTemplate,
)
from langchain_core.prompts.chat import MessagesPlaceholder
import os
import dotenv

chat_prompt_template = ChatPromptTemplate.from_messages(
    [
        {"role": "system", "content": "你是一个{role}."},
        {"role": "human", "content": ["复杂内容", {"type": "text"}]},
        MessagesPlaceholder(variable_name="mes"),
    ],
)

responses = chat_prompt_template.format_prompt(
    role="教师",
    mes=[
        HumanMessage(content="我的问题是 1+2*3=？"),
        AIMessage(content="我的问题是 1+2*3=7"),
    ],
)
print(responses)
# Out:
# messages=[SystemMessage(content='你是一个教师.', additional_kwargs={}, response_metadata={}), HumanMessage(content=[{'type': 'text', 'text': '复杂内容'}, {'type': 'text'}], additional_kwargs={}, response_metadata={}), HumanMessage(content='我的问题是 1+2*3=？', additional_kwargs={}, response_metadata={}), AIMessage(content='我的问题是 1+2*3=7', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]
